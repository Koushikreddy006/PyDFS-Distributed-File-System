# %% [markdown]
# <a href="https://colab.research.google.com/github/Koushikreddy006/PyDFS-Distributed-File-System/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("students.csv")

print("Student Data")
print(data)

print("\nAverage Marks")
print(data[['Math','Science','English']].mean())

data['Total'] = data[['Math','Science','English']].sum(axis=1)

top_student = data.loc[data['Total'].idxmax()]
print("\nTop Student:")
print(top_student)

# First Chart
data.set_index('Name')[['Math','Science','English']].plot(kind='bar')

plt.title("Student Marks Comparison")
plt.ylabel("Marks")

plt.savefig("marks_chart.png")

plt.show()


# Second Chart (PUT HERE)
# Subject average comparison
subject_avg = data[['Math','Science','English']].mean()

subject_avg.plot(kind='bar')

plt.title("Average Marks by Subject")
plt.ylabel("Average Marks")

plt.savefig("subject_average_chart.png")

plt.show()
# Out:
# Student Data
#     Name  Math  Science  English
# 0  Rahul    85       78       90
# 1  Anita    92       88       95
# 2  Kiran    70       65       72
# 3  Sneha    88       82       85
# 4  Arjun    60       58       65
# 5  Priya    95       91       89
# 6   Ravi    75       80       70
#
# Average Marks
# Math       80.714286
# Science    77.428571
# English    80.857143
# dtype: float64
#
# Top Student:
# Name       Anita
# Math          92
# Science       88
# English       95
# Total        275
# Name: 1, dtype: object
